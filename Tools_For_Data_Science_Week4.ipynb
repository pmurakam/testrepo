# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Peter Murakami**
#
# Data Scientist

# %% [markdown]
# *I am interested in data science because I want to build software tools for analysis and reporting.*

# %% [markdown]
# ### The code in cell 5 will add 1 and 2 together.

# %%
1+2
# Out:
# 3

# %% [markdown]
# Here is a horizontal rule:
# ***
#
# Here is a numbered list:
# 1. Item 1
# 2. Item 2
# 3. Item 3
#
# Here is a bulleted list:
# * Item 1
# * Item 2
#
# Here is a link to [Google](www.google.com)
